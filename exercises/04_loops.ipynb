# %% [markdown]
# 1. Sum of squares

# %%
def sum_squares(n):
    ...

# %% [markdown]
# 2. Count vowels

# %%
def count_vowels(s):
    ...

# %% [markdown]
# 3. First index

# %%
def first_index(seq, target, default=-1):
    ...

# %% [markdown]
# 4. Flatten shallow

# %%
def flatten_once(nested):
    ...

# %% [markdown]
# 5. Unique in order

# %%
def dedupe_adjacent(seq):
    ...

# %% [markdown]
# 6. Running average

# %%
def running_avg(nums):
    ...

# %% [markdown]
# 7. Matrix transpose

# %%
def transpose(m):
    ...

# %% [markdown]
# 8. Find primes

# %%
def primes_upto(n):
    ...

# %% [markdown]
# 9. Word frequency

# %%
def word_freq(text):
    ...

# %% [markdown]
# 10. Find window max

# %%
def sliding_max(nums, k):
    ...

# %% [markdown]
# 11. CSV lines to totals

# %%
def totals_by_name(lines):
    ...
